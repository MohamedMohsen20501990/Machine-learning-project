# %%
import pandas as pd

# %%
data = pd.read_csv('Airline_Delay_Cause.csv')

# %%
data.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2022      7      9E  Endeavor Air Inc.     ABE
# 1  2022      7      9E  Endeavor Air Inc.     ABY
# 2  2022      7      9E  Endeavor Air Inc.     ACK
# 3  2022      7      9E  Endeavor Air Inc.     AEX
# 4  2022      7      9E  Endeavor Air Inc.     AGS
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...         33.0        2.0
# 1             Albany, GA: Southwest Georgia Regional         78.0       25.0
# 2                  Nantucket, MA: Nantucket Memorial        124.0       19.0
# 3           Alexandria, LA: Alexandria International         67.0       10.0
# 4        Augusta, GA: Augusta Regional at Bush Field        174.0       30.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        0.92        1.00  ...          0.0              0.00            0.0
# ...

# %%
data.isna().sum()
# Out:
# year                     0
# month                    0
# carrier                  0
# carrier_name             0
# airport                  0
# airport_name             0
# arr_flights            158
# arr_del15              355
# carrier_ct             158
# weather_ct             158
# nas_ct                 158
# security_ct            158
# late_aircraft_ct       158
# arr_cancelled          158
# arr_diverted           158
# arr_delay              158
# carrier_delay          158
# weather_delay          158
# nas_delay              158
# security_delay         158
# late_aircraft_delay    158
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# year                   0
# month                  0
# carrier                0
# carrier_name           0
# airport                0
# airport_name           0
# arr_flights            0
# arr_del15              0
# carrier_ct             0
# weather_ct             0
# nas_ct                 0
# security_ct            0
# late_aircraft_ct       0
# arr_cancelled          0
# arr_diverted           0
# arr_delay              0
# carrier_delay          0
# weather_delay          0
# nas_delay              0
# security_delay         0
# late_aircraft_delay    0
# dtype: int64

# %%
# di hatsa3edny any a3mel drop lekol elhagat elli mosh numeical(objectsd)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100960 entries, 0 to 101314
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 100960 non-null  int64
#  1   month                100960 non-null  int64
#  2   carrier              100960 non-null  object
#  3   carrier_name         100960 non-null  object
#  4   airport              100960 non-null  object
#  5   airport_name         100960 non-null  object
#  6   arr_flights          100960 non-null  float64
#  7   arr_del15            100960 non-null  float64
#  8   carrier_ct           100960 non-null  float64
#  9   weather_ct           100960 non-null  float64
#  10  nas_ct               100960 non-null  float64
#  11  security_ct          100960 non-null  float64
#  12  late_aircraft_ct     100960 non-null  float64
#  13  arr_cancelled        100960 non-null  float64
# ...

# %%
data.drop(['carrier', 'carrier_name','airport', 'airport_name'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100960 entries, 0 to 101314
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 100960 non-null  int64
#  1   month                100960 non-null  int64
#  2   arr_flights          100960 non-null  float64
#  3   arr_del15            100960 non-null  float64
#  4   carrier_ct           100960 non-null  float64
#  5   weather_ct           100960 non-null  float64
#  6   nas_ct               100960 non-null  float64
#  7   security_ct          100960 non-null  float64
#  8   late_aircraft_ct     100960 non-null  float64
#  9   arr_cancelled        100960 non-null  float64
#  10  arr_diverted         100960 non-null  float64
#  11  arr_delay            100960 non-null  float64
#  12  carrier_delay        100960 non-null  float64
#  13  weather_delay        100960 non-null  float64
# ...

# %%
data
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 0       2022      7         33.0        2.0        0.92        1.00    0.08
# 1       2022      7         78.0       25.0       11.80        0.72    5.01
# 2       2022      7        124.0       19.0        5.84        1.00    6.76
# 3       2022      7         67.0       10.0        1.32        1.00    2.40
# 4       2022      7        174.0       30.0       18.10        5.75    3.60
# ...      ...    ...          ...        ...         ...         ...     ...
# 101310  2017      1       1576.0      484.0      108.28        1.27  102.71
# 101311  2017      1       2914.0      522.0      147.05       12.26  110.93
# 101312  2017      1       2390.0      447.0      140.36       17.54   79.95
# 101313  2017      1        404.0       74.0       26.29        0.28    5.20
# 101314  2017      1        372.0      139.0       26.44        0.78   13.62
#
# ...

# %%
# el column elli hashta5al 3aleh we hatwaqa3 3aleh ha3meloh drop men el data we ha3meloh lewahdo data kalati
# 1 for columns 0 for rows and inplace to overwrtie the data
x = data.drop(['late_aircraft_delay'], axis=1, inplace=False)
y =data['late_aircraft_delay']

# %%
data.head()
# Out:
#    year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 0  2022      7         33.0        2.0        0.92        1.00    0.08
# 1  2022      7         78.0       25.0       11.80        0.72    5.01
# 2  2022      7        124.0       19.0        5.84        1.00    6.76
# 3  2022      7         67.0       10.0        1.32        1.00    2.40
# 4  2022      7        174.0       30.0       18.10        5.75    3.60
#
#    security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 0          0.0              0.00            0.0           0.0      129.0
# 1          0.0              7.48            0.0           0.0     1664.0
# 2          0.0              5.40            5.0           4.0     1523.0
# 3          1.0              4.28            0.0           1.0      657.0
# 4          0.0              2.55            1.0           0.0     2462.0
#
#    carrier_delay  weather_delay  nas_delay  security_delay  \
# ...

# %%
x
# Out:
#         year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 0       2022      7         33.0        2.0        0.92        1.00    0.08
# 1       2022      7         78.0       25.0       11.80        0.72    5.01
# 2       2022      7        124.0       19.0        5.84        1.00    6.76
# 3       2022      7         67.0       10.0        1.32        1.00    2.40
# 4       2022      7        174.0       30.0       18.10        5.75    3.60
# ...      ...    ...          ...        ...         ...         ...     ...
# 101310  2017      1       1576.0      484.0      108.28        1.27  102.71
# 101311  2017      1       2914.0      522.0      147.05       12.26  110.93
# 101312  2017      1       2390.0      447.0      140.36       17.54   79.95
# 101313  2017      1        404.0       74.0       26.29        0.28    5.20
# 101314  2017      1        372.0      139.0       26.44        0.78   13.62
#
# ...

# %%
y
# Out:
# 0             0.0
# 1           501.0
# 2           589.0
# 3           354.0
# 4           327.0
#            ...
# 101310    13447.0
# 101311    13701.0
# 101312    12318.0
# 101313     1725.0
# 101314     5307.0
# Name: late_aircraft_delay, Length: 100960, dtype: float64

# %%
x.shape
# Out:
# (100960, 16)

# %%
data.shape
# Out:
# (100960, 17)

# %%
#import libraries
from sklearn.model_selection import train_test_split

#splitting the data
x_train,x_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state=44, shuffle=True)

# show the splitted data
print('x train shape is ', x_train.shape)
print('y train shape is ', y_train.shape)
print('x test shape is ', x_test.shape)
print('y test shape is ', y_test.shape)
# Out:
# x train shape is  (75720, 16)
# y train shape is  (75720,)
# x test shape is  (25240, 16)
# y test shape is  (25240,)

# %%
x_train.head()
# Out:
#        year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 33640  2020     11         29.0        5.0        1.31        1.71    1.98
# 30219  2021      2        325.0       50.0       17.04        1.90   21.42
# 44695  2020      4        288.0        7.0        5.13        0.99    0.88
# 35630  2020     10        112.0       17.0        1.59        1.16   10.99
# 65646  2019      4         60.0        7.0        3.00        0.95    1.05
#
#        security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 33640          0.0              0.00            2.0           0.0      316.0
# 30219          0.0              9.64           14.0           0.0     2640.0
# 44695          0.0              0.00           84.0           1.0      469.0
# 35630          0.0              3.26            0.0           0.0      673.0
# 65646          0.0              2.00            1.0           0.0      226.0
#
# ...

# %%
y_train.head()
# Out:
# 33640      0.0
# 30219    673.0
# 44695      0.0
# 35630    217.0
# 65646     76.0
# Name: late_aircraft_delay, dtype: float64

# %%
# import libraries to train the model after determining the x,y
from sklearn.linear_model import LinearRegression

# %%
#applting the linear regression model to the objects that i have made
LinearRegressionModel = LinearRegression(fit_intercept=True, copy_X=True, n_jobs=-1)

# %%
# %%time

# the most important step, i will always use the LinearReressionModel object to train the dataa

LinearRegressionModel.fit(x_train, y_train)
# Out:
# CPU times: total: 203 ms
# Wall time: 177 ms
# LinearRegression(n_jobs=-1)

# %%
print('Linear Regression Train Score is : ' , LinearRegressionModel.score(x_train, y_train))
# Out:
# Linear Regression Train Score is :  0.9999998870684659

# %%
#Calculating Details
# we ageb values lelweights we el b's f(x) = wx+b ahof howa gably afdal qeyam leil w's, b
print('Linear Regression Test Score is : ' , LinearRegressionModel.score(x_test, y_test))
print('Linear Regression Coef is : ' , LinearRegressionModel.coef_)
print('Linear Regression intercept is : ' , LinearRegressionModel.intercept_)
#print('----------------------------------------------------')
# Out:
# Linear Regression Test Score is :  0.9999999754695756
# Linear Regression Coef is :  [-9.37181014e-04 -1.55354256e-03 -4.14012266e-05 -1.55508892e+02
#   1.55509008e+02  1.55506555e+02  1.55509435e+02  1.55488590e+02
#   1.55509241e+02  7.06428649e-05  3.71313202e-04  9.99997604e-01
#  -9.99995146e-01 -9.99975147e-01 -1.00000311e+00 -9.99747705e-01]
# Linear Regression intercept is :  1.891100175151223

# %%
# calculating the prediction

y_pred = LinearRegressionModel.predict(x_test)
y_pred
# Out:
# array([ 1.17898440e+03,  7.51548984e+02,  6.87642863e+03, ...,
#        -1.72736392e-02,  4.37982031e+02,  1.21991654e+02])

# %%
x_test.head()
# Out:
#        year  month  arr_flights  arr_del15  carrier_ct  weather_ct  nas_ct  \
# 78333  2018      9        229.0       57.0       26.00        5.00   17.00
# 18936  2021      8        175.0       41.0       16.96        1.98    9.21
# 97128  2017      5       1094.0      356.0       76.61       35.58  141.66
# 85090  2018      3       3332.0      467.0      140.46       10.23  212.36
# 29973  2021      2        124.0       22.0        7.36        4.26    7.00
#
#        security_ct  late_aircraft_ct  arr_cancelled  arr_diverted  arr_delay  \
# 78333         0.00              9.00            3.0           0.0     3788.0
# 18936         0.74             12.12            7.0           0.0     2597.0
# 97128         0.00            102.14            8.0           2.0    24772.0
# 85090         0.72            103.22           64.0           4.0    24902.0
# 29973         0.00              3.39            3.0           3.0      871.0
#
# ...

# %%
list(y_pred)
# Out:
# [1178.9843997271305,
#  751.548984396655,
#  6876.428625296661,
#  7482.4337626999395,
#  150.5438645409974,
#  560.9720120838492,
#  805.4266985745796,
#  0.988938984288275,
#  445.4189547483367,
#  544.5076685871215,
#  80.97866749524542,
#  133.98814947265146,
#  1989.0038080130798,
#  196.98810843575657,
#  353.9947722230726,
#  -0.004117656363292532,
#  1291.5431648816448,
#  -0.00833139343056355,
#  232.42657021759032,
#  463.966136805066,
#  887.9727725708156,
#  877.9933762204907,
#  194.42691285328985,
#  2051.9798544235673,
#  1430.9964774888285,
#  852.9910781904521,
#  353.9843350917296,
#  1695.4390604658133,
#  1992.4404510063378,
#  72.99027389088965,
#  -0.019322779737478868,
#  7457.841785391785,
#  -0.004587123479993238,
#  -0.00826104369747771,
#  157.9908114416789,
#  -0.01769299262510149,
#  -0.009656515436375912,
#  1257.9851823922181,
#  187.9876614753548,
#  213.9985005792063,
#  114.97836227411142,
#  301.98168849310264,
#  -0.00705595189521091,
# ...

# %%
y_pred.shape
# Out:
# (25240,)

# %%
list(y_test)
# Out:
# [1179.0,
#  750.0,
#  6878.0,
#  7484.0,
#  149.0,
#  561.0,
#  807.0,
#  1.0,
#  447.0,
#  543.0,
#  81.0,
#  134.0,
#  1989.0,
#  197.0,
#  354.0,
#  0.0,
#  1290.0,
#  0.0,
#  234.0,
#  464.0,
#  888.0,
#  878.0,
#  196.0,
#  2052.0,
#  1431.0,
#  853.0,
#  354.0,
#  1697.0,
#  1994.0,
#  73.0,
#  0.0,
#  7458.0,
#  0.0,
#  0.0,
#  158.0,
#  0.0,
#  0.0,
#  1258.0,
#  188.0,
#  214.0,
#  115.0,
#  302.0,
#  0.0,
#  11.0,
#  21563.0,
#  0.0,
#  662.0,
#  786.0,
#  859.0,
#  339.0,
#  795.0,
#  226.0,
#  279.0,
#  2060.0,
#  531.0,
#  459.0,
#  75.0,
#  126.0,
#  380.0,
#  136.0,
#  82.0,
#  280.0,
#  92.0,
#  138.0,
#  9550.0,
#  544.0,
#  0.0,
#  329.0,
#  219.0,
#  110.0,
#  140.0,
#  129.0,
#  395.0,
#  328.0,
#  964.0,
#  0.0,
#  19.0,
#  326.0,
#  87.0,
#  0.0,
#  245.0,
#  552.0,
#  466.0,
#  0.0,
#  215.0,
#  182.0,
#  205.0,
#  14.0,
#  2429.0,
#  51.0,
#  695.0,
#  1387.0,
#  761.0,
#  19.0,
#  172.0,
#  519.0,
#  1079.0,
#  0.0,
#  409.0,
#  203.0,
#  747.0,
#  426.0,
# ...

# %%
# cost function
from sklearn.metrics import mean_squared_error

# calculating the mean squarred error

MSEvalue = mean_squared_error(y_test, y_pred, multioutput='uniform_average') # it can be raw values
print(f"Mean squared error value is: {MSEvalue}")
# Out:
# Mean squared error value is: 0.5240014864445987
